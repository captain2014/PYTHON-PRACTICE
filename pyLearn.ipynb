# %%
#python_assigning_variables
a=5

# %%
a
# Out:
# 5

# %%
a=10

# %%
a
# Out:
# 10

# %%
a+a
# Out:
# 20

# %%
a=a+a

# %%
a
# Out:
# 40

# %%
type(a)
# Out:
# int

# %%
a=10.5

# %%
type(a)
# Out:
# float

# %%
#Strings

"hello"
# Out:
# 'hello'

# %%
'hello'
# Out:
# 'hello'

# %%
'this is me'
# Out:
# 'this is me'

# %%
" I'm me"
# Out:
# " I'm me"

# %%
print("hello")
# Out:
# hello

# %%
"hell me"
"hello you"
# Out:
# 'hello you'

# %%
print("hell me")
"hello you"
# Out:
# hell me
# 'hello you'

# %%
print("hell me")
print("hello you")
# Out:
# hell me
# hello you

# %%
print(" hello \n me")
# Out:
#  hello
#  me

# %%
print(" hello \t me")
# Out:
#  hello 	 me

# %%
len("me")
# Out:
# 2

# %%
len("you amd me ")
# Out:
# 11

# %%
# string slicing and parcing
#indexing
mystring="Hello World"

# %%
mystring
# Out:
# 'Hello World'

# %%
mystring[0]
# Out:
# 'H'

# %%
mystring[8]
# Out:
# 'r'

# %%
mystring[9]
# Out:
# 'l'

# %%
mystring[-2]
# Out:
# 'l'

# %%
#slicing
mystring= "abcdefghi"

# %% [raw]
# mystring

# %%
mystring
# Out:
# 'abcdefghi'

# %%
mystring[2:]
# Out:
# 'cdefghi'

# %%
mystring[:3]
# Out:
# 'abc'

# %%
mystring[3:6]
# Out:
# 'def'

# %%
mystring[1:3]
# Out:
# 'bc'

# %%
mystring[::]
# Out:
# 'abcdefghi'

# %%
mystring[::2]
# Out:
# 'acegi'

# %%
mystring[::3]
# Out:
# 'adg'

# %%
mystring[2:7:2]
# Out:
# 'ceg'

# %%
mystring[::-1] #reversing string
# Out:
# 'ihgfedcba'

# %%
#String propertiess and methods
#Immunibility

name="sam"

# %%
#name[0]=p #error
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[105], line 1
# ----> 1 name[0]=p
#
# NameError: name 'p' is not defined

# %%
#string concatenation
x="Hello World"

# %%
x+"  is beautiful"
# Out:
# 'Hello World  is beautiful'

# %%
letter="p"

# %%
letter*10
# Out:
# 'pppppppppp'

# %%
#METHODS
x='Hello World'

# %%
x.upper()
# Out:
# 'HELLO WORLD'

# %%
x.lower()
# Out:
# 'hello world'

# %%
x.split()
# Out:
# ['Hello', 'World']

# %%
x.split('o')
# Out:
# ['Hell', ' W', 'rld']

# %%
#print formatting with strings

print("this is string{} ".format(' inserted'))
# Out:
# this is string inserted

# %%
print("the {} {} {} " . format('fox' ,'brown' ,'quick'))
# Out:
# the fox brown quick

# %%
print("the {2} {1} {0} " .format('fox' ,'brown' ,'quick'))
# Out:
# the quick brown fox

# %%
print("the {q} {b} {f} " .format(f='fox' ,b='brown' ,q='quick'))
# Out:
# the quick brown fox

# %%
#float formatting
print("the result was {r}" .format(r=result))
# Out:
# the result was 14.285714285714286

# %%
result=100/7

# %%
result
# Out:
# 14.285714285714286

# %%
print("the result was {r:1.4f}" .format(r=result))
# Out:
# the result was 14.2857

# %%
#f.string
name="Mark"

# %%
print(f'my name is {name} ')
# Out:
# my name is Mark

# %%
#list

Me=['you','he','her']

# %%
len(Me)
# Out:
# 3

# %%
Me[0]
# Out:
# 'you'

# %%
Me[1:]
# Out:
# ['he', 'her']

# %%
them=['that','this']

# %%
Me+them
# Out:
# ['you', 'he', 'her', 'that', 'this']

# %%
they=Me+them

# %%
they
# Out:
# ['you', 'he', 'her', 'that', 'this']

# %%
they[0]="Hello" #mutable

# %%
they
# Out:
# ['Hello', 'he', 'her', 'that', 'this']

# %%
they.append('world')

# %%
they
# Out:
# ['Hello', 'he', 'her', 'that', 'this', 'world']

# %%
they.pop()
# Out:
# 'world'

# %%
they
# Out:
# ['Hello', 'he', 'her', 'that', 'this']

# %%
#dictionary
dict={'key1':'a', 'key2':'b'}

# %%
dict['key1']
# Out:
# 'a'

# %%
d={'k1':123, 'k2':[1,2,3], 'k3':{'insidekey':100}}

# %%
d['k2']
# Out:
# [1, 2, 3]

# %%
d['k3']
# Out:
# {'insidekey': 100}

# %%
d['insidekey']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[214], line 1
# ----> 1 d['insidekey']
#
# KeyError: 'insidekey'

# %%
d['k3']['insidekey']
# Out:
# 100

# %%
d={'kk1':'a,b,c'}

# %%
d.values()
# Out:
# dict_values(['a,b,c'])

# %%
d.keys()
# Out:
# dict_keys(['kk1'])

# %%
d.items()
# Out:
# dict_items([('kk1', 'a,b,c')])

# %%
list=d['kk1'][2]

# %%
list
# Out:
# 'b'

# %%
list.upper()
# Out:
# 'B'

# %%
#tuple

# %%
#sets
myset=set()

# %%
myset
# Out:
# set()

# %%
myset.add(1)

# %%
myset
# Out:
# {1}

# %%
mylist=[1,1,1,2,2,2,3,3,3]

# %%
set(mylist)
# Out:
# {1, 2, 3}

# %%
#boolean
1>2
# Out:
# False

# %%
1==1
# Out:
# True

# %%
#files
# %%writefile my.txt
ahshdkdkfkvnvbjd
ansbvkvkfmjvkvv
# Out:
# UsageError: Line magic function `%%writefile` not found.

# %%
my.txt
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[292], line 1
# ----> 1 my.txt
#
# NameError: name 'my' is not defined

# %%
 myfile= open(my.txt)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[294], line 1
# ----> 1 myfile= open(my.txt)
#
# NameError: name 'my' is not defined

# %%
pwd
# Out:
# 'C:\\Users\\Lohith L'

# %%
# %load_ext lPython.core.magic
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[302], line 1
# ----> 1 get_ipython().run_line_magic('load_ext', 'lPython.core.magic')
#
# File ~\anaconda3\Lib\site-packages\IPython\core\interactiveshell.py:2480, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2478     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2479 with self.builtin_trap:
# -> 2480     result = fn(*args, **kwargs)
#    2482 # The code below prevents the output from being displayed
#    2483 # when using magics with decorator @output_can_be_silenced
#    2484 # when the last Python token in the expression is a ';'.
#    2485 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~\anaconda3\Lib\site-packages\IPython\core\magics\extension.py:33, in ExtensionMagics.load_ext(self, module_str)
#      31 if not module_str:
# ...
